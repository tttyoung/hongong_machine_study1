# %% [markdown]
# <a href="https://colab.research.google.com/github/tttyoung/hongong_machine_study1/blob/main/week07/%EC%9E%84%EB%B3%91%ED%9A%8C/Chapter08/%ED%98%BC%EA%B3%B5%EB%A8%B8_08_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 케라스 합성곱층
from tensorflow import keras
keras.layers.Conv2D(10,kernal_size=(3,3),activation='relu')
# 세임 패딩
keras.layers.Conv2D(10,kernal_size=(3,3),activation='relu',padding='same')
# 스트라이드
keras.layers.Conv2D(10,kernal_size=(3,3),activation='relu',padding='same',strides=1)
# 맥스풀링
keras.layers.MaxPooling2D(2)
# 평균풀링
keras.layers.AveragePooling2D(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1754851197.py in <cell line: 0>()
#       1 # 케라스 합성곱층
#       2 from tensorflow import keras
# ----> 3 keras.layers.Conv2D(10,kernal_size=(3,3),activation='relu')
#       4 # 세임 패딩
#       5 keras.layers.Conv2D(10,kernal_size=(3,3),activation='relu',padding='same')
#
# TypeError: Conv2D.__init__() missing 1 required positional argument: 'kernel_size'
